# %% [markdown]
# # Merging Climate Datasets Exercise
#
# Work through this notebook to practice harmonizing and merging two climate datasets that differ in temporal cadence and spatial resolution.
#
# You will:
# - Load two public NOAA datasets directly from the cloud
# - Subset to the continental US (use 230°E–300°E in longitude since the data span 0–360°)
# - Use `xr.resample` to aggregate time and `xr.interp` to match grids
# - Combine the variables with `xr.merge` for joint analysis
#
# Refer back to the answer key after attempting each step.

# %% [markdown]
# ## 1. Setup

# %%
import matplotlib.pyplot as plt
import xarray as xr

try:
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature
except ImportError:
    ccrs = None
    cfeature = None

TEMP_URL = "https://psl.noaa.gov/thredds/dodsC/Datasets/ncep.reanalysis/surface/air.sig995.2020.nc"
PRECIP_URL = "https://psl.noaa.gov/thredds/dodsC/Datasets/cpc_global_precip/precip.2020.nc"

LAT_RANGE = slice(50, 20)  # degrees North
LON_RANGE_360 = slice(230, 300)  # degrees East (equivalent to -130° to -60°)
LON_RANGE_180 = slice(-130, -60)  # convenience if a dataset uses -180° to 180°

TIME_RANGE = slice("2020-06-01", "2020-06-30")

# %% [markdown]
# ## 2. Load the datasets
#
# Open both remote datasets with `xr.open_dataset`, passing a reasonable chunk size for the time dimension. Assign the resulting objects to `air` and `precip`.

# %%
# TODO: load the air temperature and precipitation datasets.
# Example: air = xr.open_dataset(..., chunks={"time": 8})
# raise NotImplementedError("Assign datasets to `air` and `precip`.")
air = xr.open_dataset(TEMP_URL, chunks={"time": 8}) # time step is 6 hours
precip = xr.open_dataset(PRECIP_URL, chunks={"time": 8}) # time step is daily

# %%
air
# Out:
# <xarray.Dataset> Size: 62MB
# Dimensions:  (time: 1464, lat: 73, lon: 144)
# Coordinates:
#   * lat      (lat) float32 292B 90.0 87.5 85.0 82.5 ... -82.5 -85.0 -87.5 -90.0
#   * lon      (lon) float32 576B 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 12kB 2020-01-01 ... 2020-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 62MB dask.array<chunksize=(8, 73, 144), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
precip
# Out:
# <xarray.Dataset> Size: 379MB
# Dimensions:  (time: 366, lat: 360, lon: 720)
# Coordinates:
#   * lat      (lat) float32 1kB 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * lon      (lon) float32 3kB 0.25 0.75 1.25 1.75 ... 358.2 358.8 359.2 359.8
#   * time     (time) datetime64[ns] 3kB 2020-01-01 2020-01-02 ... 2020-12-31
# Data variables:
#     precip   (time, lat, lon) float32 379MB dask.array<chunksize=(8, 360, 720), meta=np.ndarray>
# Attributes:
#     _NCProperties:                   version=1|netcdflibversion=4.4.1.1|hdf5l...
#     Conventions:                     CF-1.0
#     version:                         V1.0
#     title:                           CPC GLOBAL PRCP V1.0 RT
#     dataset_title:                   CPC GLOBAL PRCP V1.0
#     Source:                          ftp://ftp.cpc.ncep.noaa.gov/precip/CPC_U...
#     References:                      https://www.psl.noaa.gov/data/gridded/da...
#     history:                         Updated 2021-01-02 23:31:03
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 3. Subset to the continental United States and June 2020
#
# Select the bounding box provided above and limit the time range to June 2020 for both datasets. Store the results in `air_us` and `precip_us`.
# Remember that longitude runs from 0° to 360°, so select 230°E–300°E. Check whether each coordinate is ascending or descending before building the slice.

# %%
# TODO: subset both datasets using `sel`, handling coordinate ordering as needed.
# raise NotImplementedError("Create `air_us` and `precip_us`.")

air_us = air.sel(time=TIME_RANGE, lat=LAT_RANGE, lon=LON_RANGE_360)
precip_us = precip.sel(time=TIME_RANGE, lat=LAT_RANGE, lon=LON_RANGE_360)

# %%
air_us
# Out:
# <xarray.Dataset> Size: 182kB
# Dimensions:  (time: 120, lat: 13, lon: 29)
# Coordinates:
#   * lat      (lat) float32 52B 50.0 47.5 45.0 42.5 40.0 ... 27.5 25.0 22.5 20.0
#   * lon      (lon) float32 116B 230.0 232.5 235.0 237.5 ... 295.0 297.5 300.0
#   * time     (time) datetime64[ns] 960B 2020-06-01 ... 2020-06-30T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 181kB dask.array<chunksize=(8, 13, 29), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
precip_us
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:  (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * lat      (lat) float32 240B 49.75 49.25 48.75 48.25 ... 21.25 20.75 20.25
#   * lon      (lon) float32 560B 230.2 230.8 231.2 231.8 ... 298.8 299.2 299.8
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
# Data variables:
#     precip   (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>
# Attributes:
#     _NCProperties:                   version=1|netcdflibversion=4.4.1.1|hdf5l...
#     Conventions:                     CF-1.0
#     version:                         V1.0
#     title:                           CPC GLOBAL PRCP V1.0 RT
#     dataset_title:                   CPC GLOBAL PRCP V1.0
#     Source:                          ftp://ftp.cpc.ncep.noaa.gov/precip/CPC_U...
#     References:                      https://www.psl.noaa.gov/data/gridded/da...
#     history:                         Updated 2021-01-02 23:31:03
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 4. Align temporal cadence
#
# Aggregate the six-hourly air temperatures to daily means with `xr.resample`. Name the resulting DataArray `air_daily`.

# %%
# TODO: use xr.resample to create daily means.
# raise NotImplementedError("Create `air_daily`.")

air_daily = air_us.resample(time="1D").mean()
air_daily
# Out:
# <xarray.Dataset> Size: 46kB
# Dimensions:  (time: 30, lat: 13, lon: 29)
# Coordinates:
#   * lat      (lat) float32 52B 50.0 47.5 45.0 42.5 40.0 ... 27.5 25.0 22.5 20.0
#   * lon      (lon) float32 116B 230.0 232.5 235.0 237.5 ... 295.0 297.5 300.0
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
# Data variables:
#     air      (time, lat, lon) float32 45kB dask.array<chunksize=(1, 13, 29), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 5. Interpolate to the precipitation grid
#
# Use `xr.interp` to interpolate the daily air temperatures onto the precipitation grid (`precip_us.lat` and `precip_us.lon`). Store the interpolated result in `air_interp`.

# %%
# TODO: interpolate the resampled temperature field onto the precipitation grid.
# raise NotImplementedError("Create `air_interp`.")

air_interp = air_daily.interp(lat=precip_us.lat, lon=precip_us.lon)
air_interp
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:  (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
#   * lat      (lat) float32 240B 49.75 49.25 48.75 48.25 ... 21.25 20.75 20.25
#   * lon      (lon) float32 560B 230.2 230.8 231.2 231.8 ... 298.8 299.2 299.8
# Data variables:
#     air      (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 6. Merge the datasets
#
# Convert the aligned arrays into datasets with clear variable names and merge them with `xr.merge`. Save the output as `merged`.

# %%
# TODO: build datasets and merge them into one object named `merged`.
# raise NotImplementedError("Create `merged`.")

merged = xr.merge([air_interp, precip_us], join="inner")
merged
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:  (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
#   * lat      (lat) float32 240B 49.75 49.25 48.75 48.25 ... 21.25 20.75 20.25
#   * lon      (lon) float32 560B 230.2 230.8 231.2 231.8 ... 298.8 299.2 299.8
# Data variables:
#     air      (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
#     precip   (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
merged = merged.rename({"air": "air_temperature", "precip": "daily_precip"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jc/711xkp256bz0pq8mq4dcp94h0000gn/T/ipykernel_60944/2482348578.py in ?()
# ----> 1 merged = merged.rename({"air": "air_temperature", "precip": "daily_precip"})
#       2 merged
#
# /opt/anaconda3/envs/xarray-climate/lib/python3.13/site-packages/xarray/core/dataset.py in ?(self, name_dict, **names)
#    4221         Dataset.rename_vars
#    4222         Dataset.rename_dims
#    4223         DataArray.rename
#    4224         """
# -> 4225         return self._rename(name_dict=name_dict, **names)
#
# /opt/anaconda3/envs/xarray-climate/lib/python3.13/site-packages/xarray/core/dataset.py in ?(self, name_dict, **names)
#    4159         """
#    4160         name_dict = either_dict_or_kwargs(name_dict, names, "rename")
#    4161         for k in name_dict.keys():
#    4162             if k not in self and k not in self.dims:
# -> 4163                 raise ValueError(
#    4164                     f"cannot rename {k!r} because it is not a "
#    4165                     "variable or dimension in this dataset"
#    4166                 )
#
# ValueError: cannot rename 'air' because it is not a variable or dimension in this dataset

# %%
merged
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:          (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time             (time) datetime64[ns] 240B 2020-06-01 ... 2020-06-30
#   * lat              (lat) float32 240B 49.75 49.25 48.75 ... 21.25 20.75 20.25
#   * lon              (lon) float32 560B 230.2 230.8 231.2 ... 298.8 299.2 299.8
# Data variables:
#     air_temperature  (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
#     daily_precip     (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 7. Inspect your result
#
# Once your pipeline runs without `NotImplementedError`, evaluate the following cell to sanity-check the merged dataset.

# %%
# The assertions below should pass once you have completed the exercise.
assert set(merged.data_vars) == {"air_temperature", "daily_precip"}
assert merged.air_temperature.dims == merged.daily_precip.dims
print(merged)
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:          (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time             (time) datetime64[ns] 240B 2020-06-01 ... 2020-06-30
#   * lat              (lat) float32 240B 49.75 49.25 48.75 ... 21.25 20.75 20.25
#   * lon              (lon) float32 560B 230.2 230.8 231.2 ... 298.8 299.2 299.8
# Data variables:
#     air_temperature  (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
#     daily_precip     (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 8. Check In
#
# - Render both variables at the first timestep on a `cartopy` map to verify alignment visually (PlateCarree works well).
# - Build a scatter plot comparing colocated temperature and precipitation values across the merged domain.
# - Save the merged output with `to_netcdf` for future analysis.

# %%
# Plotting both variables to verify alignment
# first timestep

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

fig, axes = plt.subplots(1, 2, figsize=(16, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Plot air temperature
im1 = merged.air_temperature.isel(time=0).plot(
    ax=axes[0], transform=ccrs.PlateCarree(), cmap='coolwarm', 
    cbar_kwargs={'shrink': .4, 'aspect': 10, 'pad': 0.02}  # shrinking the colorbar so it's the same height as the plot
)
axes[0].set_title('Air Temperature (First Timestep)')
axes[0].coastlines()

# Plot daily precipitation
im2 = merged.daily_precip.isel(time=0).plot(
    ax=axes[1], transform=ccrs.PlateCarree(), cmap='Blues', 
    cbar_kwargs={'shrink': .4, 'aspect': 10, 'pad': 0.02}  # shrinking the colorbar so it's the same height as the plot
)
axes[1].set_title('Daily Precipitation (First Timestep)')
axes[1].coastlines()

plt.tight_layout()
plt.savefig("merged_temp_precip_plot_time0.png", dpi=300)
plt.show()

# Only have precip over land, but otherwise, alignment looks good.

# %%
# Checking for NaNs in the merged dataset
print("NaNs in air_temperature:", merged.air_temperature.isnull().sum().compute())
print("NaNs in daily_precip:", merged.daily_precip.isnull().sum().compute())

# no NaNs in air_temperature, but many in daily_precip (due to land-only data).
# will have to remove NaNs before creating scatterplot since ocean points will have temp but not precip data.
# Out:
# NaNs in air_temperature: <xarray.DataArray 'air_temperature' ()> Size: 8B
# array(0)
# NaNs in daily_precip: <xarray.DataArray 'daily_precip' ()> Size: 8B
# array(105840)

# %%
# Layer each day in a different color to construct a scatterplot of all 30 days within the temporal domain

import numpy as np

# Create a colormap for the days
num_days = merged.dims['time']
cmap = plt.get_cmap('tab20', num_days)

plt.figure(figsize=(8, 6))

for day in range(num_days):
    temp = merged.air_temperature.isel(time=day)
    precip = merged.daily_precip.isel(time=day)
    x = temp.values.flatten()  # converting 2D grid to 1D array
    y = precip.values.flatten()   # converting 2D grid to 1D array
    mask = (~np.isnan(x)) & (~np.isnan(y)) # only plot points with both temp and precip data (i.e. over land)
    x_valid = x[mask]
    y_valid = y[mask]
    plt.scatter(x_valid, y_valid, alpha=0.5, s=10, color=cmap(day), label=f'Day {day+1}')

plt.xlabel("Air Temperature (K)")
plt.ylabel("Daily Precipitation (mm)")
plt.title("Scatterplot of Temperature vs. Precipitation (All Days)")
plt.grid(True)
plt.legend(markerscale=2, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("temp_precip_scatterplot_all_days.png", dpi=300)
plt.show()

# Max precip occured on days when daily mean temp was 297 - 302K (~75-85°F)
# Out:
# /var/folders/jc/711xkp256bz0pq8mq4dcp94h0000gn/T/ipykernel_60944/3956687034.py:6: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_days = merged.dims['time']

# %%
# Getting error about a string name not matching, so duplicating the DS to a new name
merged2 = merged

# attributes seem to be causing the problem when attempting to save the dataset as netCDF, so deleting the attributes
for attr in list(merged2.attrs):
    del merged2.attrs[attr]

merged2.to_netcdf("merged_temp_precip.nc")
